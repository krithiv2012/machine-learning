# %%
import pandas as pd
import numpy as np

# %%
data = [
    ['Nissan', 'Stanza', 1991, 138, 4, 'MANUAL', 'sedan', 2000],
    ['Hyundai', 'Sonata', 2017, None, 4, 'AUTOMATIC', 'Sedan', 27150],
    ['Lotus', 'Elise', 2010, 218, 4, 'MANUAL', 'convertible', 54990],
    ['GMC', 'Acadia',  2017, 194, 4, 'AUTOMATIC', '4dr SUV', 34450],
    ['Nissan', 'Frontier', 2017, 261, 6, 'MANUAL', 'Pickup', 32340],
]

columns = [
    'Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
    'Transmission Type', 'Vehicle_Style', 'MSRP'
]

# %%
df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df['id'] = [1,2,3,4,5]

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000   1
# 1         Sedan  27150   2
# 2   convertible  54990   3
# 3       4dr SUV  34450   4
# 4        Pickup  32340   5

# %%
del df['id']

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.MSRP.values
# Out:
# array([ 2000, 27150, 54990, 34450, 32340])

# %%
pd.__version__
# Out:
# '3.0.6'

# %%
import kagglehub
path = kagglehub.dataset_download("notebooks/01-intro")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglehub/exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglehub/http_resolver.py:364, in _get_current_version.<locals>.<lambda>()
#     363 r.dataset_slug = h.dataset
# --> 364 dataset = handle_call(lambda: api_client.datasets.dataset_api_client.get_dataset(r))
#     365 return dataset.current_version_number
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglesdk/datasets/services/dataset_api_service.py:33, in DatasetApiClient.get_dataset(self, request)
#      31   request = ApiGetDatasetRequest()
# ---> 33 return self._client.call("datasets.DatasetApiService", "GetDataset", request, ApiDataset)
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglesdk/kaggle_http_client.py:106, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#     104 http_response = self._session.send(http_request, **settings)
# --> 106 response = self._prepare_response(response_type, http_response)
#     107 return response
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglesdk/kaggle_http_client.py:134, in KaggleHttpClient._prepare_response(self, response_type, http_response)
#     133   pass
# --> 134 http_response.raise_for_status()
#     135 # Allow client to check header content.
#
# File ~/.local/lib/python3.14/site-packages/requests/models.py:1167, in Response.raise_for_status(self)
#    1166 if http_error_msg:
# -> 1167     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDataset
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# Cell In[14], line 2
#       1 import kagglehub
# ----> 2 path = kagglehub.dataset_download("notebooks/01-intro")
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglehub/datasets.py:52, in dataset_download(handle, path, force_download, output_dir)
#      50 h = parse_dataset_handle(handle)
#      51 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52 resolved_path, _ = registry.dataset_resolver(
#      53     h,
#      54     path,
#      55     force_download=force_download,
#      56     output_dir=output_dir,
#      57 )
#      58 return resolved_path
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglehub/registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglehub/resolver.py:35, in Resolver.__call__(self, handle, path, force_download, output_dir)
#      15 def __call__(
#      16     self,
#      17     handle: T,
#    (...)     21     output_dir: str | None = None,
#      22 ) -> tuple[str, int | None]:
#      23     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      24
#      25     Args:
#    (...)     33         Some cases where version number might be missing: Competition datasource, API-based models.
#      34     """
# ---> 35     path, version = self._resolve(
#      36         handle,
#      37         path,
#      38         force_download=force_download,
#      39         output_dir=output_dir,
#      40     )
#      42     # Note handles are immutable, so _resolve() could not have altered our reference
#      43     register_datasource_access(handle, version)
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglehub/http_resolver.py:125, in DatasetHttpResolver._resolve(self, h, path, force_download, output_dir)
#     123 with build_kaggle_client() as api_client:
#     124     if not h.is_versioned():
# --> 125         h = h.with_version(_get_current_version(api_client, h))
#     127     cache = Cache(override_dir=output_dir)
#     128     dataset_path = cache.load_from_cache(h, path)
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglehub/http_resolver.py:364, in _get_current_version(api_client, h)
#     362     r.owner_slug = h.owner
#     363     r.dataset_slug = h.dataset
# --> 364     dataset = handle_call(lambda: api_client.datasets.dataset_api_client.get_dataset(r))
#     365     return dataset.current_version_number
#     367 elif isinstance(h, NotebookHandle):
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/kagglehub/exceptions.py:107, in handle_call(fn, resource_handle)
#      98     message = (
#      99         f"{e.response.status_code} Client Error."
#     100         "\n\n"
#    (...)    103         "Please make sure you specified the correct resource identifiers."
#     104     )
#     106 # Default handling
# --> 107 raise KaggleApiHTTPError(message, response=e.response) from e
#
# KaggleApiHTTPError: 403 Client Error.
#
# You don't have permission to access resource at URL: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDataset. Please make sure you are authenticated if you are trying to access a private resource or a resource requiring consent.
